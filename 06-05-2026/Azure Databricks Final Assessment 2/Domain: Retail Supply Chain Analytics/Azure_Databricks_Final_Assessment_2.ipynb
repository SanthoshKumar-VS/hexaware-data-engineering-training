# %% [markdown]
# **Azure Databricks Final Assessment 2 - executing commands in google colab because credits gets exhausted in azure**

# %% [markdown]
# **Domain: Retail Supply Chain Analytics**

# %% [markdown]
# **Part 0 — Prepare Bigger Dataset**

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

spark = SparkSession.builder\
.appName("Retail Supply Chain Analytics")\
.getOrCreate()

# %% [markdown]
# **products_data**

# %%
products_data = [
(101,"Rice Bag","Groceries","Hyderabad",1200,50),
(102,"Wheat Flour","Groceries","Bengaluru",900,80),
(103,"Sunflower Oil","Groceries","Mumbai",1800,40),
(104,"Milk Pack","Dairy","Chennai",60,200),
(105,"Cheese Block","Dairy","Delhi",450,70),
(106,"Soap","Personal Care","Kolkata",120,300),
(107,"Shampoo","Personal Care","Pune",320,150),
(108,"Toothpaste","Personal Care","Ahmedabad",90,250),
(109,"Notebook","Stationery","Hyderabad",75,500),
(110,"Pen Pack","Stationery","Mumbai",110,400),
(111,"LED TV","Electronics","Delhi",45000,15),
(112,"Refrigerator","Electronics","Chennai",38000,10),
(113,"Washing Machine","Electronics","Bengaluru",29000,12),
(114,"Mobile Phone","Electronics","Hyderabad",25000,35),
(115,"Laptop","Electronics","Pune",62000,18),
(116,"Air Conditioner","Electronics","Mumbai",42000,9),
(117,"Mixer Grinder","Home Appliances","Kolkata",3500,45),
(118,"Water Purifier","Home Appliances","Delhi",12000,20),
(119,"Ceiling Fan","Home Appliances","Ahmedabad",2800,60),
(120,"Gas Stove","Home Appliances","Chennai",5500,25)
]

products_columns = [
"product_id",
"product_name",
"category",
"warehouse_city",
"price",
"stock_quantity"
]

products_df = spark.createDataFrame(
products_data,products_columns
)

# %% [markdown]
# **suppliers_data**

# %%
suppliers_data = [
(201,"Reddy Traders","Hyderabad","Groceries"),
(202,"Fresh Dairy Ltd","Chennai","Dairy"),
(203,"CarePlus Suppliers","Mumbai","Personal Care"),
(204,"Elite Electronics","Delhi","Electronics"),
(205,"OfficeKart","Bengaluru","Stationery"),
(206,"HomeNeeds Pvt Ltd","Pune","Home Appliances"),
(207,"National Grocers","Ahmedabad","Groceries"),
(208,"Smart Electronics","Kolkata","Electronics"),
(209,"Daily Essentials","Hyderabad","Personal Care"),
(210,"Kitchen World","Chennai","Home Appliances")
]

suppliers_columns = [
"supplier_id",
"supplier_name",
"supplier_city",
"specialization"
]

suppliers_df = spark.createDataFrame(
suppliers_data,suppliers_columns
)

# %% [markdown]
# **orders_data**

# %%
orders_data = [
(301,101,201,"2024-04-01",20,"Delivered"),
(302,102,201,"2024-04-01",35,"Delivered"),
(303,111,204,"2024-04-02",2,"Delivered"),
(304,114,208,"2024-04-02",5,"Pending"),
(305,115,204,"2024-04-03",3,"Delivered"),
(306,104,202,"2024-04-03",50,"Delivered"),
(307,105,202,"2024-04-04",18,"Cancelled"),
(308,117,206,"2024-04-04",7,"Delivered"),
(309,118,210,"2024-04-05",4,"Pending"),
(310,119,206,"2024-04-05",12,"Delivered"),
(311,120,210,"2024-04-06",6,"Delivered"),
(312,113,204,"2024-04-06",4,"Delivered"),
(313,116,208,"2024-04-07",2,"Pending"),
(314,109,205,"2024-04-07",80,"Delivered"),
(315,110,205,"2024-04-08",120,"Delivered"),
(316,106,203,"2024-04-08",60,"Cancelled"),
(317,107,209,"2024-04-09",25,"Delivered"),
(318,108,203,"2024-04-09",40,"Delivered"),
(319,112,208,"2024-04-10",2,"Pending"),
(320,101,207,"2024-04-10",15,"Delivered")
]

orders_columns = [
"order_id",
"product_id",
"supplier_id",
"order_date",
"quantity",
"order_status"
]

orders_df = spark.createDataFrame(
orders_data,orders_columns
)

# %% [markdown]
# **payments_data**

# %%
payments_data = [
(401,301,24000,"UPI","Paid"),
(402,302,31500,"Credit Card","Paid"),
(403,303,90000,"Bank Transfer","Paid"),
(404,304,125000,"UPI","Pending"),
(405,305,186000,"Bank Transfer","Paid"),
(406,306,3000,"Cash","Paid"),
(407,307,8100,"UPI","Cancelled"),
(408,308,24500,"Debit Card","Paid"),
(409,309,48000,"UPI","Pending"),
(410,310,33600,"Cash","Paid"),
(411,311,33000,"Credit Card","Paid"),
(412,312,116000,"Bank Transfer","Paid"),
(413,313,84000,"UPI","Pending"),
(414,314,6000,"Cash","Paid"),
(415,315,13200,"UPI","Paid"),
(416,316,7200,"Cash","Cancelled"),
(417,317,8000,"UPI","Paid"),
(418,318,3600,"Debit Card","Paid"),
(419,319,76000,"Bank Transfer","Pending"),
(420,320,18000,"UPI","Paid")
]

payments_columns = [
"payment_id",
"order_id",
"bill_amount",
"payment_mode",
"payment_status"
]

payments_df = spark.createDataFrame(
payments_data,payments_columns
)

# %% [markdown]
# **Assessment Tasks**

# %% [markdown]
# **Part 1 — DataFrame Fundamentals**

# %%
products_df.show()
suppliers_df.show()
orders_df.show()
payments_df.show()
# Out:
# +----------+---------------+---------------+--------------+-----+--------------+
# |product_id|   product_name|       category|warehouse_city|price|stock_quantity|
# +----------+---------------+---------------+--------------+-----+--------------+
# |       101|       Rice Bag|      Groceries|     Hyderabad| 1200|            50|
# |       102|    Wheat Flour|      Groceries|     Bengaluru|  900|            80|
# |       103|  Sunflower Oil|      Groceries|        Mumbai| 1800|            40|
# |       104|      Milk Pack|          Dairy|       Chennai|   60|           200|
# |       105|   Cheese Block|          Dairy|         Delhi|  450|            70|
# |       106|           Soap|  Personal Care|       Kolkata|  120|           300|
# |       107|        Shampoo|  Personal Care|          Pune|  320|           150|
# |       108|     Toothpaste|  Personal Care|     Ahmedabad|   90|           250|
# |       109|       Notebook|     Stationery|     Hyderabad|   75|           500|
# ...

# %%
products_df.printSchema()
suppliers_df.printSchema()
orders_df.printSchema()
payments_df.printSchema()
# Out:
# root
#  |-- product_id: long (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- warehouse_city: string (nullable = true)
#  |-- price: long (nullable = true)
#  |-- stock_quantity: long (nullable = true)
#
# root
#  |-- supplier_id: long (nullable = true)
#  |-- supplier_name: string (nullable = true)
#  |-- supplier_city: string (nullable = true)
#  |-- specialization: string (nullable = true)
#
# root
#  |-- order_id: long (nullable = true)
#  |-- product_id: long (nullable = true)
#  |-- supplier_id: long (nullable = true)
#  |-- order_date: string (nullable = true)
#  |-- quantity: long (nullable = true)
#  |-- order_status: string (nullable = true)
#
# root
#  |-- payment_id: long (nullable = true)
#  |-- order_id: long (nullable = true)
#  |-- bill_amount: long (nullable = true)
#  |-- payment_mode: string (nullable = true)
#  |-- payment_status: string (nullable = true)

# %%
products_df.count()
suppliers_df.count()
orders_df.count()
payments_df.count()
# Out:
# 20

# %%
products_df.show(10)
# Out:
# +----------+-------------+-------------+--------------+-----+--------------+
# |product_id| product_name|     category|warehouse_city|price|stock_quantity|
# +----------+-------------+-------------+--------------+-----+--------------+
# |       101|     Rice Bag|    Groceries|     Hyderabad| 1200|            50|
# |       102|  Wheat Flour|    Groceries|     Bengaluru|  900|            80|
# |       103|Sunflower Oil|    Groceries|        Mumbai| 1800|            40|
# |       104|    Milk Pack|        Dairy|       Chennai|   60|           200|
# |       105| Cheese Block|        Dairy|         Delhi|  450|            70|
# |       106|         Soap|Personal Care|       Kolkata|  120|           300|
# |       107|      Shampoo|Personal Care|          Pune|  320|           150|
# |       108|   Toothpaste|Personal Care|     Ahmedabad|   90|           250|
# |       109|     Notebook|   Stationery|     Hyderabad|   75|           500|
# ...

# %%
products_df.select(
"product_name",
"category",
"stock_quantity"
).show()
# Out:
# +---------------+---------------+--------------+
# |   product_name|       category|stock_quantity|
# +---------------+---------------+--------------+
# |       Rice Bag|      Groceries|            50|
# |    Wheat Flour|      Groceries|            80|
# |  Sunflower Oil|      Groceries|            40|
# |      Milk Pack|          Dairy|           200|
# |   Cheese Block|          Dairy|            70|
# |           Soap|  Personal Care|           300|
# |        Shampoo|  Personal Care|           150|
# |     Toothpaste|  Personal Care|           250|
# |       Notebook|     Stationery|           500|
# |       Pen Pack|     Stationery|           400|
# |         LED TV|    Electronics|            15|
# |   Refrigerator|    Electronics|            10|
# |Washing Machine|    Electronics|            12|
# |   Mobile Phone|    Electronics|            35|
# |         Laptop|    Electronics|            18|
# |Air Conditioner|    Electronics|             9|
# ...

# %%
suppliers_df.filter(
col("supplier_city").isin(
"Hyderabad","Chennai")
).show()
# Out:
# +-----------+----------------+-------------+---------------+
# |supplier_id|   supplier_name|supplier_city| specialization|
# +-----------+----------------+-------------+---------------+
# |        201|   Reddy Traders|    Hyderabad|      Groceries|
# |        202| Fresh Dairy Ltd|      Chennai|          Dairy|
# |        209|Daily Essentials|    Hyderabad|  Personal Care|
# |        210|   Kitchen World|      Chennai|Home Appliances|
# +-----------+----------------+-------------+---------------+

# %%
orders_df.filter(
col("order_status")=="Delivered"
).show()
# Out:
# +--------+----------+-----------+----------+--------+------------+
# |order_id|product_id|supplier_id|order_date|quantity|order_status|
# +--------+----------+-----------+----------+--------+------------+
# |     301|       101|        201|2024-04-01|      20|   Delivered|
# |     302|       102|        201|2024-04-01|      35|   Delivered|
# |     303|       111|        204|2024-04-02|       2|   Delivered|
# |     305|       115|        204|2024-04-03|       3|   Delivered|
# |     306|       104|        202|2024-04-03|      50|   Delivered|
# |     308|       117|        206|2024-04-04|       7|   Delivered|
# |     310|       119|        206|2024-04-05|      12|   Delivered|
# |     311|       120|        210|2024-04-06|       6|   Delivered|
# |     312|       113|        204|2024-04-06|       4|   Delivered|
# |     314|       109|        205|2024-04-07|      80|   Delivered|
# |     315|       110|        205|2024-04-08|     120|   Delivered|
# ...

# %%
orders_df.filter(
col("order_status")=="Pending"
).show()
# Out:
# +--------+----------+-----------+----------+--------+------------+
# |order_id|product_id|supplier_id|order_date|quantity|order_status|
# +--------+----------+-----------+----------+--------+------------+
# |     304|       114|        208|2024-04-02|       5|     Pending|
# |     309|       118|        210|2024-04-05|       4|     Pending|
# |     313|       116|        208|2024-04-07|       2|     Pending|
# |     319|       112|        208|2024-04-10|       2|     Pending|
# +--------+----------+-----------+----------+--------+------------+

# %%
products_df.filter(
col("category")=="Electronics"
).show()
# Out:
# +----------+---------------+-----------+--------------+-----+--------------+
# |product_id|   product_name|   category|warehouse_city|price|stock_quantity|
# +----------+---------------+-----------+--------------+-----+--------------+
# |       111|         LED TV|Electronics|         Delhi|45000|            15|
# |       112|   Refrigerator|Electronics|       Chennai|38000|            10|
# |       113|Washing Machine|Electronics|     Bengaluru|29000|            12|
# |       114|   Mobile Phone|Electronics|     Hyderabad|25000|            35|
# |       115|         Laptop|Electronics|          Pune|62000|            18|
# |       116|Air Conditioner|Electronics|        Mumbai|42000|             9|
# +----------+---------------+-----------+--------------+-----+--------------+

# %%
products_df.filter(
col("stock_quantity") < 20
).show()
# Out:
# +----------+---------------+-----------+--------------+-----+--------------+
# |product_id|   product_name|   category|warehouse_city|price|stock_quantity|
# +----------+---------------+-----------+--------------+-----+--------------+
# |       111|         LED TV|Electronics|         Delhi|45000|            15|
# |       112|   Refrigerator|Electronics|       Chennai|38000|            10|
# |       113|Washing Machine|Electronics|     Bengaluru|29000|            12|
# |       115|         Laptop|Electronics|          Pune|62000|            18|
# |       116|Air Conditioner|Electronics|        Mumbai|42000|             9|
# +----------+---------------+-----------+--------------+-----+--------------+

# %% [markdown]
# **Part 2 — DataFrame Transformations**

# %%
orders_df = orders_df.withColumn(
"order_date",
to_date(col("order_date"),"yyyy-MM-dd")
)
orders_df.show()
# Out:
# +--------+----------+-----------+----------+--------+------------+
# |order_id|product_id|supplier_id|order_date|quantity|order_status|
# +--------+----------+-----------+----------+--------+------------+
# |     301|       101|        201|2024-04-01|      20|   Delivered|
# |     302|       102|        201|2024-04-01|      35|   Delivered|
# |     303|       111|        204|2024-04-02|       2|   Delivered|
# |     304|       114|        208|2024-04-02|       5|     Pending|
# |     305|       115|        204|2024-04-03|       3|   Delivered|
# |     306|       104|        202|2024-04-03|      50|   Delivered|
# |     307|       105|        202|2024-04-04|      18|   Cancelled|
# |     308|       117|        206|2024-04-04|       7|   Delivered|
# |     309|       118|        210|2024-04-05|       4|     Pending|
# |     310|       119|        206|2024-04-05|      12|   Delivered|
# |     311|       120|        210|2024-04-06|       6|   Delivered|
# ...

# %%
final_orders_df = orders_df.join(
products_df,
on="product_id",
how="inner"
)

final_orders_df = final_orders_df.withColumn(
"total_order_value",
col("quantity") * col("price")
)

final_orders_df.show()
# Out:
# +----------+--------+-----------+----------+--------+------------+---------------+---------------+--------------+-----+--------------+-----------------+
# |product_id|order_id|supplier_id|order_date|quantity|order_status|   product_name|       category|warehouse_city|price|stock_quantity|total_order_value|
# +----------+--------+-----------+----------+--------+------------+---------------+---------------+--------------+-----+--------------+-----------------+
# |       101|     301|        201|2024-04-01|      20|   Delivered|       Rice Bag|      Groceries|     Hyderabad| 1200|            50|            24000|
# |       101|     320|        207|2024-04-10|      15|   Delivered|       Rice Bag|      Groceries|     Hyderabad| 1200|            50|            18000|
# |       102|     302|        201|2024-04-01|      35|   Delivered|    Wheat Flour|      Groceries|     Bengaluru|  900|            80|            31500|
# ...

# %%
products_df = products_df.withColumn(
"stock_status",
when(col("stock_quantity") < 20,"Low")
.otherwise("Available")
)

products_df.show()
# Out:
# +----------+---------------+---------------+--------------+-----+--------------+------------+
# |product_id|   product_name|       category|warehouse_city|price|stock_quantity|stock_status|
# +----------+---------------+---------------+--------------+-----+--------------+------------+
# |       101|       Rice Bag|      Groceries|     Hyderabad| 1200|            50|   Available|
# |       102|    Wheat Flour|      Groceries|     Bengaluru|  900|            80|   Available|
# |       103|  Sunflower Oil|      Groceries|        Mumbai| 1800|            40|   Available|
# |       104|      Milk Pack|          Dairy|       Chennai|   60|           200|   Available|
# |       105|   Cheese Block|          Dairy|         Delhi|  450|            70|   Available|
# |       106|           Soap|  Personal Care|       Kolkata|  120|           300|   Available|
# |       107|        Shampoo|  Personal Care|          Pune|  320|           150|   Available|
# ...

# %%
orders_df = orders_df.withColumn(
"order_priority",
when(col("quantity") >= 50,"High")
.otherwise("Normal")
)

orders_df.show()
# Out:
# +--------+----------+-----------+----------+--------+------------+--------------+
# |order_id|product_id|supplier_id|order_date|quantity|order_status|order_priority|
# +--------+----------+-----------+----------+--------+------------+--------------+
# |     301|       101|        201|2024-04-01|      20|   Delivered|        Normal|
# |     302|       102|        201|2024-04-01|      35|   Delivered|        Normal|
# |     303|       111|        204|2024-04-02|       2|   Delivered|        Normal|
# |     304|       114|        208|2024-04-02|       5|     Pending|        Normal|
# |     305|       115|        204|2024-04-03|       3|   Delivered|        Normal|
# |     306|       104|        202|2024-04-03|      50|   Delivered|          High|
# |     307|       105|        202|2024-04-04|      18|   Cancelled|        Normal|
# |     308|       117|        206|2024-04-04|       7|   Delivered|        Normal|
# ...

# %%
products_df = products_df.withColumn(
"expensive_product_flag",
when(col("price") > 30000,"Yes")
.otherwise("No")
)

products_df.show()
# Out:
# +----------+---------------+---------------+--------------+-----+--------------+------------+----------------------+
# |product_id|   product_name|       category|warehouse_city|price|stock_quantity|stock_status|expensive_product_flag|
# +----------+---------------+---------------+--------------+-----+--------------+------------+----------------------+
# |       101|       Rice Bag|      Groceries|     Hyderabad| 1200|            50|   Available|                    No|
# |       102|    Wheat Flour|      Groceries|     Bengaluru|  900|            80|   Available|                    No|
# |       103|  Sunflower Oil|      Groceries|        Mumbai| 1800|            40|   Available|                    No|
# |       104|      Milk Pack|          Dairy|       Chennai|   60|           200|   Available|                    No|
# |       105|   Cheese Block|          Dairy|         Delhi|  450|            70|   Available|                    No|
# ...

# %%
products_df = products_df.withColumn(
"category",
upper(col("category"))
)

products_df.show()
# Out:
# +----------+---------------+---------------+--------------+-----+--------------+------------+----------------------+
# |product_id|   product_name|       category|warehouse_city|price|stock_quantity|stock_status|expensive_product_flag|
# +----------+---------------+---------------+--------------+-----+--------------+------------+----------------------+
# |       101|       Rice Bag|      GROCERIES|     Hyderabad| 1200|            50|   Available|                    No|
# |       102|    Wheat Flour|      GROCERIES|     Bengaluru|  900|            80|   Available|                    No|
# |       103|  Sunflower Oil|      GROCERIES|        Mumbai| 1800|            40|   Available|                    No|
# |       104|      Milk Pack|          DAIRY|       Chennai|   60|           200|   Available|                    No|
# |       105|   Cheese Block|          DAIRY|         Delhi|  450|            70|   Available|                    No|
# ...

# %%
products_df = products_df.withColumnRenamed(
"warehouse_city",
"inventory_city"
)

products_df.show()
# Out:
# +----------+---------------+---------------+--------------+-----+--------------+------------+----------------------+
# |product_id|   product_name|       category|inventory_city|price|stock_quantity|stock_status|expensive_product_flag|
# +----------+---------------+---------------+--------------+-----+--------------+------------+----------------------+
# |       101|       Rice Bag|      GROCERIES|     Hyderabad| 1200|            50|   Available|                    No|
# |       102|    Wheat Flour|      GROCERIES|     Bengaluru|  900|            80|   Available|                    No|
# |       103|  Sunflower Oil|      GROCERIES|        Mumbai| 1800|            40|   Available|                    No|
# |       104|      Milk Pack|          DAIRY|       Chennai|   60|           200|   Available|                    No|
# |       105|   Cheese Block|          DAIRY|         Delhi|  450|            70|   Available|                    No|
# ...

# %%
products_df = products_df.withColumn(
"inventory_value",
col("price") * col("stock_quantity")
)

products_df.show()
# Out:
# +----------+---------------+---------------+--------------+-----+--------------+------------+----------------------+---------------+
# |product_id|   product_name|       category|inventory_city|price|stock_quantity|stock_status|expensive_product_flag|inventory_value|
# +----------+---------------+---------------+--------------+-----+--------------+------------+----------------------+---------------+
# |       101|       Rice Bag|      GROCERIES|     Hyderabad| 1200|            50|   Available|                    No|          60000|
# |       102|    Wheat Flour|      GROCERIES|     Bengaluru|  900|            80|   Available|                    No|          72000|
# |       103|  Sunflower Oil|      GROCERIES|        Mumbai| 1800|            40|   Available|                    No|          72000|
# |       104|      Milk Pack|          DAIRY|       Chennai|   60|           200|   Available|                    No|          12000|
# ...

# %%
products_df = products_df.drop(
"expensive_product_flag"
)

products_df.show()
# Out:
# +----------+---------------+---------------+--------------+-----+--------------+------------+---------------+
# |product_id|   product_name|       category|inventory_city|price|stock_quantity|stock_status|inventory_value|
# +----------+---------------+---------------+--------------+-----+--------------+------------+---------------+
# |       101|       Rice Bag|      GROCERIES|     Hyderabad| 1200|            50|   Available|          60000|
# |       102|    Wheat Flour|      GROCERIES|     Bengaluru|  900|            80|   Available|          72000|
# |       103|  Sunflower Oil|      GROCERIES|        Mumbai| 1800|            40|   Available|          72000|
# |       104|      Milk Pack|          DAIRY|       Chennai|   60|           200|   Available|          12000|
# |       105|   Cheese Block|          DAIRY|         Delhi|  450|            70|   Available|          31500|
# ...

# %%
products_df = products_df.withColumn(
"low_stock_flag",
when(col("stock_quantity") < 15,"Yes")
.otherwise("No")
)

products_df.show()
# Out:
# +----------+---------------+---------------+--------------+-----+--------------+------------+---------------+--------------+
# |product_id|   product_name|       category|inventory_city|price|stock_quantity|stock_status|inventory_value|low_stock_flag|
# +----------+---------------+---------------+--------------+-----+--------------+------------+---------------+--------------+
# |       101|       Rice Bag|      GROCERIES|     Hyderabad| 1200|            50|   Available|          60000|            No|
# |       102|    Wheat Flour|      GROCERIES|     Bengaluru|  900|            80|   Available|          72000|            No|
# |       103|  Sunflower Oil|      GROCERIES|        Mumbai| 1800|            40|   Available|          72000|            No|
# |       104|      Milk Pack|          DAIRY|       Chennai|   60|           200|   Available|          12000|            No|
# ...

# %% [markdown]
# **Part 3 — Joins**

# %%
product_orders_df = products_df.join(
orders_df,
on="product_id",
how="inner"
)

product_orders_df.show()
# Out:
# +----------+---------------+---------------+--------------+-----+--------------+------------+---------------+--------------+--------+-----------+----------+--------+------------+--------------+
# |product_id|   product_name|       category|inventory_city|price|stock_quantity|stock_status|inventory_value|low_stock_flag|order_id|supplier_id|order_date|quantity|order_status|order_priority|
# +----------+---------------+---------------+--------------+-----+--------------+------------+---------------+--------------+--------+-----------+----------+--------+------------+--------------+
# |       101|       Rice Bag|      GROCERIES|     Hyderabad| 1200|            50|   Available|          60000|            No|     301|        201|2024-04-01|      20|   Delivered|        Normal|
# |       101|       Rice Bag|      GROCERIES|     Hyderabad| 1200|            50|   Available|          60000|            No|     320|        207|2024-04-10|      15|   Delivered|        Normal|
# ...

# %%
order_supplier_df = orders_df.join(
suppliers_df,
on="supplier_id",
how="inner"
)

order_supplier_df.show()
# Out:
# +-----------+--------+----------+----------+--------+------------+--------------+------------------+-------------+---------------+
# |supplier_id|order_id|product_id|order_date|quantity|order_status|order_priority|     supplier_name|supplier_city| specialization|
# +-----------+--------+----------+----------+--------+------------+--------------+------------------+-------------+---------------+
# |        201|     301|       101|2024-04-01|      20|   Delivered|        Normal|     Reddy Traders|    Hyderabad|      Groceries|
# |        201|     302|       102|2024-04-01|      35|   Delivered|        Normal|     Reddy Traders|    Hyderabad|      Groceries|
# |        202|     306|       104|2024-04-03|      50|   Delivered|          High|   Fresh Dairy Ltd|      Chennai|          Dairy|
# |        202|     307|       105|2024-04-04|      18|   Cancelled|        Normal|   Fresh Dairy Ltd|      Chennai|          Dairy|
# ...

# %%
order_payment_df = orders_df.join(
payments_df,
on="order_id",
how="inner"
)

order_payment_df.show()
# Out:
# +--------+----------+-----------+----------+--------+------------+--------------+----------+-----------+-------------+--------------+
# |order_id|product_id|supplier_id|order_date|quantity|order_status|order_priority|payment_id|bill_amount| payment_mode|payment_status|
# +--------+----------+-----------+----------+--------+------------+--------------+----------+-----------+-------------+--------------+
# |     301|       101|        201|2024-04-01|      20|   Delivered|        Normal|       401|      24000|          UPI|          Paid|
# |     302|       102|        201|2024-04-01|      35|   Delivered|        Normal|       402|      31500|  Credit Card|          Paid|
# |     303|       111|        204|2024-04-02|       2|   Delivered|        Normal|       403|      90000|Bank Transfer|          Paid|
# |     304|       114|        208|2024-04-02|       5|     Pending|        Normal|       404|     125000|          UPI|       Pending|
# ...

# %%
final_joined_df = products_df\
.join(orders_df,on="product_id")\
.join(suppliers_df,on="supplier_id")\
.join(payments_df,on="order_id")

final_joined_df.show()
# Out:
# +--------+-----------+----------+---------------+---------------+--------------+-----+--------------+------------+---------------+--------------+----------+--------+------------+--------------+------------------+-------------+---------------+----------+-----------+-------------+--------------+
# |order_id|supplier_id|product_id|   product_name|       category|inventory_city|price|stock_quantity|stock_status|inventory_value|low_stock_flag|order_date|quantity|order_status|order_priority|     supplier_name|supplier_city| specialization|payment_id|bill_amount| payment_mode|payment_status|
# +--------+-----------+----------+---------------+---------------+--------------+-----+--------------+------------+---------------+--------------+----------+--------+------------+--------------+------------------+-------------+---------------+----------+-----------+-------------+--------------+
# ...

# %%
final_joined_df.select(
"product_name",
"supplier_name",
"quantity",
"bill_amount"
).show()
# Out:
# +---------------+------------------+--------+-----------+
# |   product_name|     supplier_name|quantity|bill_amount|
# +---------------+------------------+--------+-----------+
# |       Rice Bag|     Reddy Traders|      20|      24000|
# |    Wheat Flour|     Reddy Traders|      35|      31500|
# |         LED TV| Elite Electronics|       2|      90000|
# |   Mobile Phone| Smart Electronics|       5|     125000|
# |         Laptop| Elite Electronics|       3|     186000|
# |      Milk Pack|   Fresh Dairy Ltd|      50|       3000|
# |   Cheese Block|   Fresh Dairy Ltd|      18|       8100|
# |  Mixer Grinder| HomeNeeds Pvt Ltd|       7|      24500|
# | Water Purifier|     Kitchen World|       4|      48000|
# |    Ceiling Fan| HomeNeeds Pvt Ltd|      12|      33600|
# |      Gas Stove|     Kitchen World|       6|      33000|
# |Washing Machine| Elite Electronics|       4|     116000|
# |Air Conditioner| Smart Electronics|       2|      84000|
# ...

# %%
final_joined_df.filter(
col("inventory_city") !=
col("supplier_city")
).select(
"product_name",
"inventory_city",
"supplier_name",
"supplier_city"
).show()
# Out:
# +---------------+--------------+------------------+-------------+
# |   product_name|inventory_city|     supplier_name|supplier_city|
# +---------------+--------------+------------------+-------------+
# |    Wheat Flour|     Bengaluru|     Reddy Traders|    Hyderabad|
# |   Mobile Phone|     Hyderabad| Smart Electronics|      Kolkata|
# |         Laptop|          Pune| Elite Electronics|        Delhi|
# |   Cheese Block|         Delhi|   Fresh Dairy Ltd|      Chennai|
# |  Mixer Grinder|       Kolkata| HomeNeeds Pvt Ltd|         Pune|
# | Water Purifier|         Delhi|     Kitchen World|      Chennai|
# |    Ceiling Fan|     Ahmedabad| HomeNeeds Pvt Ltd|         Pune|
# |Washing Machine|     Bengaluru| Elite Electronics|        Delhi|
# |Air Conditioner|        Mumbai| Smart Electronics|      Kolkata|
# |       Notebook|     Hyderabad|        OfficeKart|    Bengaluru|
# |       Pen Pack|        Mumbai|        OfficeKart|    Bengaluru|
# ...

# %%
final_joined_df.filter(
(col("order_status")=="Delivered") &
(col("payment_status")=="Paid")
).show()
# Out:
# +--------+-----------+----------+---------------+---------------+--------------+-----+--------------+------------+---------------+--------------+----------+--------+------------+--------------+------------------+-------------+---------------+----------+-----------+-------------+--------------+
# |order_id|supplier_id|product_id|   product_name|       category|inventory_city|price|stock_quantity|stock_status|inventory_value|low_stock_flag|order_date|quantity|order_status|order_priority|     supplier_name|supplier_city| specialization|payment_id|bill_amount| payment_mode|payment_status|
# +--------+-----------+----------+---------------+---------------+--------------+-----+--------------+------------+---------------+--------------+----------+--------+------------+--------------+------------------+-------------+---------------+----------+-----------+-------------+--------------+
# ...

# %%
final_joined_df.filter(
(col("order_status")=="Pending") &
(col("payment_status")=="Pending")
).show()
# Out:
# +--------+-----------+----------+---------------+---------------+--------------+-----+--------------+------------+---------------+--------------+----------+--------+------------+--------------+-----------------+-------------+---------------+----------+-----------+-------------+--------------+
# |order_id|supplier_id|product_id|   product_name|       category|inventory_city|price|stock_quantity|stock_status|inventory_value|low_stock_flag|order_date|quantity|order_status|order_priority|    supplier_name|supplier_city| specialization|payment_id|bill_amount| payment_mode|payment_status|
# +--------+-----------+----------+---------------+---------------+--------------+-----+--------------+------------+---------------+--------------+----------+--------+------------+--------------+-----------------+-------------+---------------+----------+-----------+-------------+--------------+
# ...

# %%
final_joined_df.filter(
(col("order_status")=="Cancelled") &
(col("payment_status")=="Cancelled")
).show()
# Out:
# +--------+-----------+----------+------------+-------------+--------------+-----+--------------+------------+---------------+--------------+----------+--------+------------+--------------+------------------+-------------+--------------+----------+-----------+------------+--------------+
# |order_id|supplier_id|product_id|product_name|     category|inventory_city|price|stock_quantity|stock_status|inventory_value|low_stock_flag|order_date|quantity|order_status|order_priority|     supplier_name|supplier_city|specialization|payment_id|bill_amount|payment_mode|payment_status|
# +--------+-----------+----------+------------+-------------+--------------+-----+--------------+------------+---------------+--------------+----------+--------+------------+--------------+------------------+-------------+--------------+----------+-----------+------------+--------------+
# ...

# %%
final_joined_df.groupBy(
"product_id",
"product_name"
).count().filter(
col("count") > 1
).show()
# Out:
# +----------+------------+-----+
# |product_id|product_name|count|
# +----------+------------+-----+
# |       101|    Rice Bag|    2|
# +----------+------------+-----+

# %% [markdown]
# **Part 4 — Aggregations**

# %%
products_df.groupBy(
"category"
).count().show()
# Out:
# +---------------+-----+
# |       category|count|
# +---------------+-----+
# |      GROCERIES|    3|
# |          DAIRY|    2|
# |     STATIONERY|    2|
# |  PERSONAL CARE|    3|
# |    ELECTRONICS|    6|
# |HOME APPLIANCES|    4|
# +---------------+-----+

# %%
orders_df.groupBy(
"order_status"
).count().show()
# Out:
# +------------+-----+
# |order_status|count|
# +------------+-----+
# |   Cancelled|    2|
# |   Delivered|   14|
# |     Pending|    4|
# +------------+-----+

# %%
suppliers_df.groupBy(
"supplier_city"
).count().show()
# Out:
# +-------------+-----+
# |supplier_city|count|
# +-------------+-----+
# |      Chennai|    2|
# |       Mumbai|    1|
# |        Delhi|    1|
# |    Bengaluru|    1|
# |    Hyderabad|    2|
# |    Ahmedabad|    1|
# |      Kolkata|    1|
# |         Pune|    1|
# +-------------+-----+

# %%
payments_df.agg(
sum("bill_amount")
.alias("total_revenue")
).show()
# Out:
# +-------------+
# |total_revenue|
# +-------------+
# |       938700|
# +-------------+

# %%
payments_df.agg(
avg("bill_amount")
.alias("average_bill")
).show()
# Out:
# +------------+
# |average_bill|
# +------------+
# |     46935.0|
# +------------+

# %%
final_joined_df.groupBy(
"category"
).agg(
sum("bill_amount")
.alias("total_revenue")
).show()
# Out:
# +---------------+-------------+
# |       category|total_revenue|
# +---------------+-------------+
# |      GROCERIES|        73500|
# |          DAIRY|        11100|
# |    ELECTRONICS|       677000|
# |     STATIONERY|        19200|
# |  PERSONAL CARE|        18800|
# |HOME APPLIANCES|       139100|
# +---------------+-------------+

# %%
final_joined_df.groupBy(
"supplier_name"
).agg(
sum("bill_amount")
.alias("total_revenue")
).show()
# Out:
# +------------------+-------------+
# |     supplier_name|total_revenue|
# +------------------+-------------+
# |     Reddy Traders|        55500|
# | HomeNeeds Pvt Ltd|        58100|
# |   Fresh Dairy Ltd|        11100|
# |     Kitchen World|        81000|
# | Elite Electronics|       392000|
# |  National Grocers|        18000|
# |        OfficeKart|        19200|
# | Smart Electronics|       285000|
# |CarePlus Suppliers|        10800|
# |  Daily Essentials|         8000|
# +------------------+-------------+

# %%
final_joined_df.groupBy(
"supplier_city"
).agg(
sum("bill_amount")
.alias("total_revenue")
).show()
# Out:
# +-------------+-------------+
# |supplier_city|total_revenue|
# +-------------+-------------+
# |      Chennai|        92100|
# |       Mumbai|        10800|
# |    Ahmedabad|        18000|
# |      Kolkata|       285000|
# |         Pune|        58100|
# |        Delhi|       392000|
# |    Bengaluru|        19200|
# |    Hyderabad|        63500|
# +-------------+-------------+

# %%
final_joined_df.groupBy(
"product_name"
).agg(
sum("quantity")
.alias("total_quantity")
).orderBy(
col("total_quantity").desc()
).show()
# Out:
# +---------------+--------------+
# |   product_name|total_quantity|
# +---------------+--------------+
# |       Pen Pack|           120|
# |       Notebook|            80|
# |           Soap|            60|
# |      Milk Pack|            50|
# |     Toothpaste|            40|
# |       Rice Bag|            35|
# |    Wheat Flour|            35|
# |        Shampoo|            25|
# |   Cheese Block|            18|
# |    Ceiling Fan|            12|
# |  Mixer Grinder|             7|
# |      Gas Stove|             6|
# |   Mobile Phone|             5|
# |Washing Machine|             4|
# | Water Purifier|             4|
# |         Laptop|             3|
# |   Refrigerator|             2|
# |Air Conditioner|             2|
# |         LED TV|             2|
# +---------------+--------------+

# %%
  final_joined_df.groupBy(
"product_name"
).agg(
sum("quantity")
.alias("total_quantity")
).orderBy(
col("total_quantity").asc()
).show()
# Out:
# +---------------+--------------+
# |   product_name|total_quantity|
# +---------------+--------------+
# |   Refrigerator|             2|
# |Air Conditioner|             2|
# |         LED TV|             2|
# |         Laptop|             3|
# |Washing Machine|             4|
# | Water Purifier|             4|
# |   Mobile Phone|             5|
# |      Gas Stove|             6|
# |  Mixer Grinder|             7|
# |    Ceiling Fan|            12|
# |   Cheese Block|            18|
# |        Shampoo|            25|
# |       Rice Bag|            35|
# |    Wheat Flour|            35|
# |     Toothpaste|            40|
# |      Milk Pack|            50|
# |           Soap|            60|
# |       Notebook|            80|
# |       Pen Pack|           120|
# +---------------+--------------+

# %% [markdown]
# **Part 5 — Spark SQL**

# %%
products_df.createOrReplaceTempView(
"products"
)
suppliers_df.createOrReplaceTempView(
"suppliers"
)
orders_df.createOrReplaceTempView(
"orders"
)
payments_df.createOrReplaceTempView(
"payments"
)
final_joined_df.createOrReplaceTempView(
"final_data"
)

# %%
spark.sql(
"select * from products"
).show()
# Out:
# +----------+---------------+---------------+--------------+-----+--------------+------------+---------------+--------------+
# |product_id|   product_name|       category|inventory_city|price|stock_quantity|stock_status|inventory_value|low_stock_flag|
# +----------+---------------+---------------+--------------+-----+--------------+------------+---------------+--------------+
# |       101|       Rice Bag|      GROCERIES|     Hyderabad| 1200|            50|   Available|          60000|            No|
# |       102|    Wheat Flour|      GROCERIES|     Bengaluru|  900|            80|   Available|          72000|            No|
# |       103|  Sunflower Oil|      GROCERIES|        Mumbai| 1800|            40|   Available|          72000|            No|
# |       104|      Milk Pack|          DAIRY|       Chennai|   60|           200|   Available|          12000|            No|
# ...

# %%
spark.sql(
"select * from final_data where category='ELECTRONICS'"
).show()
# Out:
# +--------+-----------+----------+---------------+-----------+--------------+-----+--------------+------------+---------------+--------------+----------+--------+------------+--------------+-----------------+-------------+--------------+----------+-----------+-------------+--------------+
# |order_id|supplier_id|product_id|   product_name|   category|inventory_city|price|stock_quantity|stock_status|inventory_value|low_stock_flag|order_date|quantity|order_status|order_priority|    supplier_name|supplier_city|specialization|payment_id|bill_amount| payment_mode|payment_status|
# +--------+-----------+----------+---------------+-----------+--------------+-----+--------------+------------+---------------+--------------+----------+--------+------------+--------------+-----------------+-------------+--------------+----------+-----------+-------------+--------------+
# ...

# %%
spark.sql(
"select category,sum(bill_amount) as total_revenue from final_data group by category"
).show()
# Out:
# +---------------+-------------+
# |       category|total_revenue|
# +---------------+-------------+
# |      GROCERIES|        73500|
# |          DAIRY|        11100|
# |    ELECTRONICS|       677000|
# |     STATIONERY|        19200|
# |  PERSONAL CARE|        18800|
# |HOME APPLIANCES|       139100|
# +---------------+-------------+

# %%
spark.sql(
"select supplier_name,sum(bill_amount) as total_revenue from final_data group by supplier_name"
).show()
# Out:
# +------------------+-------------+
# |     supplier_name|total_revenue|
# +------------------+-------------+
# |     Reddy Traders|        55500|
# | HomeNeeds Pvt Ltd|        58100|
# |   Fresh Dairy Ltd|        11100|
# |     Kitchen World|        81000|
# | Elite Electronics|       392000|
# |  National Grocers|        18000|
# |        OfficeKart|        19200|
# | Smart Electronics|       285000|
# |CarePlus Suppliers|        10800|
# |  Daily Essentials|         8000|
# +------------------+-------------+

# %%
spark.sql(
"select * from final_data order by bill_amount desc limit 5"
).show()
# Out:
# +--------+-----------+----------+---------------+-----------+--------------+-----+--------------+------------+---------------+--------------+----------+--------+------------+--------------+-----------------+-------------+--------------+----------+-----------+-------------+--------------+
# |order_id|supplier_id|product_id|   product_name|   category|inventory_city|price|stock_quantity|stock_status|inventory_value|low_stock_flag|order_date|quantity|order_status|order_priority|    supplier_name|supplier_city|specialization|payment_id|bill_amount| payment_mode|payment_status|
# +--------+-----------+----------+---------------+-----------+--------------+-----+--------------+------------+---------------+--------------+----------+--------+------------+--------------+-----------------+-------------+--------------+----------+-----------+-------------+--------------+
# ...

# %%
spark.sql(
"select supplier_name,count(*) as total_orders from final_data group by supplier_name"
).show()
# Out:
# +------------------+------------+
# |     supplier_name|total_orders|
# +------------------+------------+
# |     Reddy Traders|           2|
# | HomeNeeds Pvt Ltd|           2|
# |   Fresh Dairy Ltd|           2|
# |     Kitchen World|           2|
# | Elite Electronics|           3|
# |  National Grocers|           1|
# |        OfficeKart|           2|
# | Smart Electronics|           3|
# |CarePlus Suppliers|           2|
# |  Daily Essentials|           1|
# +------------------+------------+

# %%
spark.sql(
"select category,count(*) as total_orders from final_data group by category"
).show()
# Out:
# +---------------+------------+
# |       category|total_orders|
# +---------------+------------+
# |      GROCERIES|           3|
# |          DAIRY|           2|
# |    ELECTRONICS|           6|
# |     STATIONERY|           2|
# |  PERSONAL CARE|           3|
# |HOME APPLIANCES|           4|
# +---------------+------------+

# %%
spark.sql(
"select payment_mode,avg(bill_amount) as avg_payment from final_data group by payment_mode"
).show()
# Out:
# +-------------+-----------+
# | payment_mode|avg_payment|
# +-------------+-----------+
# |  Credit Card|    32250.0|
# |Bank Transfer|   117000.0|
# |         Cash|    12450.0|
# |   Debit Card|    14050.0|
# |          UPI|    41037.5|
# +-------------+-----------+

# %%
spark.sql(
"select product_name,sum(bill_amount) as total_revenue from final_data group by product_name having sum(bill_amount)>100000"
).show()
# Out:
# +---------------+-------------+
# |   product_name|total_revenue|
# +---------------+-------------+
# |         Laptop|       186000|
# |Washing Machine|       116000|
# |   Mobile Phone|       125000|
# +---------------+-------------+

# %% [markdown]
# **Part 6 — Window Functions**

# %%
from pyspark.sql.window import Window

cat_window = Window.partitionBy(
"category"
).orderBy(
col("bill_amount").desc()
)

final_joined_df.withColumn(
"rank",
rank().over(cat_window)
).select(
"product_name",
"category",
"bill_amount",
"rank"
).show()
# Out:
# +---------------+---------------+-----------+----+
# |   product_name|       category|bill_amount|rank|
# +---------------+---------------+-----------+----+
# |   Cheese Block|          DAIRY|       8100|   1|
# |      Milk Pack|          DAIRY|       3000|   2|
# |         Laptop|    ELECTRONICS|     186000|   1|
# |   Mobile Phone|    ELECTRONICS|     125000|   2|
# |Washing Machine|    ELECTRONICS|     116000|   3|
# |         LED TV|    ELECTRONICS|      90000|   4|
# |Air Conditioner|    ELECTRONICS|      84000|   5|
# |   Refrigerator|    ELECTRONICS|      76000|   6|
# |    Wheat Flour|      GROCERIES|      31500|   1|
# |       Rice Bag|      GROCERIES|      24000|   2|
# |       Rice Bag|      GROCERIES|      18000|   3|
# | Water Purifier|HOME APPLIANCES|      48000|   1|
# |    Ceiling Fan|HOME APPLIANCES|      33600|   2|
# |      Gas Stove|HOME APPLIANCES|      33000|   3|
# |  Mixer Grinder|HOME APPLIANCES|      24500|   4|
# ...

# %%
city_window = Window.partitionBy(
"supplier_city"
).orderBy(
col("bill_amount").desc()
)

final_joined_df.withColumn(
"rank",
rank().over(city_window)
).select(
"supplier_name",
"supplier_city",
"bill_amount",
"rank"
).show()
# Out:
# +------------------+-------------+-----------+----+
# |     supplier_name|supplier_city|bill_amount|rank|
# +------------------+-------------+-----------+----+
# |  National Grocers|    Ahmedabad|      18000|   1|
# |        OfficeKart|    Bengaluru|      13200|   1|
# |        OfficeKart|    Bengaluru|       6000|   2|
# |     Kitchen World|      Chennai|      48000|   1|
# |     Kitchen World|      Chennai|      33000|   2|
# |   Fresh Dairy Ltd|      Chennai|       8100|   3|
# |   Fresh Dairy Ltd|      Chennai|       3000|   4|
# | Elite Electronics|        Delhi|     186000|   1|
# | Elite Electronics|        Delhi|     116000|   2|
# | Elite Electronics|        Delhi|      90000|   3|
# |     Reddy Traders|    Hyderabad|      31500|   1|
# |     Reddy Traders|    Hyderabad|      24000|   2|
# |  Daily Essentials|    Hyderabad|       8000|   3|
# | Smart Electronics|      Kolkata|     125000|   1|
# | Smart Electronics|      Kolkata|      84000|   2|
# ...

# %%
row_window = Window.partitionBy(
"category"
).orderBy(
col("bill_amount").desc()
)

final_joined_df.withColumn(
"row_num",
row_number().over(row_window)
).filter(
col("row_num")==1
).select(
"product_name",
"category",
"bill_amount"
).show()
# Out:
# +--------------+---------------+-----------+
# |  product_name|       category|bill_amount|
# +--------------+---------------+-----------+
# |  Cheese Block|          DAIRY|       8100|
# |        Laptop|    ELECTRONICS|     186000|
# |   Wheat Flour|      GROCERIES|      31500|
# |Water Purifier|HOME APPLIANCES|      48000|
# |       Shampoo|  PERSONAL CARE|       8000|
# |      Pen Pack|     STATIONERY|      13200|
# +--------------+---------------+-----------+

# %%
dense_window = Window.partitionBy(
"supplier_city"
).orderBy(
col("bill_amount").desc()
)

final_joined_df.withColumn(
"dense_rank",
dense_rank().over(dense_window)
).select(
"supplier_name",
"supplier_city",
"bill_amount",
"dense_rank"
).show()
# Out:
# +------------------+-------------+-----------+----------+
# |     supplier_name|supplier_city|bill_amount|dense_rank|
# +------------------+-------------+-----------+----------+
# |  National Grocers|    Ahmedabad|      18000|         1|
# |        OfficeKart|    Bengaluru|      13200|         1|
# |        OfficeKart|    Bengaluru|       6000|         2|
# |     Kitchen World|      Chennai|      48000|         1|
# |     Kitchen World|      Chennai|      33000|         2|
# |   Fresh Dairy Ltd|      Chennai|       8100|         3|
# |   Fresh Dairy Ltd|      Chennai|       3000|         4|
# | Elite Electronics|        Delhi|     186000|         1|
# | Elite Electronics|        Delhi|     116000|         2|
# | Elite Electronics|        Delhi|      90000|         3|
# |     Reddy Traders|    Hyderabad|      31500|         1|
# |     Reddy Traders|    Hyderabad|      24000|         2|
# |  Daily Essentials|    Hyderabad|       8000|         3|
# ...

# %%
supplier_revenue = final_joined_df.groupBy(
"supplier_name"
).agg(
sum("bill_amount")
.alias("total_revenue")
)

top_window = Window.orderBy(
col("total_revenue").desc()
)

supplier_revenue.withColumn(
"rank",
rank().over(top_window)
).filter(
col("rank")<=2
).show()
# Out:
# +-----------------+-------------+----+
# |    supplier_name|total_revenue|rank|
# +-----------------+-------------+----+
# |Elite Electronics|       392000|   1|
# |Smart Electronics|       285000|   2|
# +-----------------+-------------+----+

# %%
date_window = Window.orderBy(
"order_date"
)

final_joined_df.withColumn(
"running_total",
sum("bill_amount").over(date_window)
).select(
"order_date",
"bill_amount",
"running_total"
).show()
# Out:
# +----------+-----------+-------------+
# |order_date|bill_amount|running_total|
# +----------+-----------+-------------+
# |2024-04-01|      24000|        55500|
# |2024-04-01|      31500|        55500|
# |2024-04-02|      90000|       270500|
# |2024-04-02|     125000|       270500|
# |2024-04-03|     186000|       459500|
# |2024-04-03|       3000|       459500|
# |2024-04-04|       8100|       492100|
# |2024-04-04|      24500|       492100|
# |2024-04-05|      48000|       573700|
# |2024-04-05|      33600|       573700|
# |2024-04-06|      33000|       722700|
# |2024-04-06|     116000|       722700|
# |2024-04-07|      84000|       812700|
# |2024-04-07|       6000|       812700|
# |2024-04-08|      13200|       833100|
# |2024-04-08|       7200|       833100|
# |2024-04-09|       8000|       844700|
# |2024-04-09|       3600|       844700|
# |2024-04-10|      76000|       938700|
# |2024-04-10|      18000|       938700|
# +----------+-----------+-------------+

# %%
supplier_window = Window.partitionBy(
"supplier_name"
).orderBy(
"order_date"
)

final_joined_df.withColumn(
"running_total",
sum("bill_amount").over(supplier_window)
).select(
"supplier_name",
"order_date",
"bill_amount",
"running_total"
).show()
# Out:
# +------------------+----------+-----------+-------------+
# |     supplier_name|order_date|bill_amount|running_total|
# +------------------+----------+-----------+-------------+
# |CarePlus Suppliers|2024-04-08|       7200|         7200|
# |CarePlus Suppliers|2024-04-09|       3600|        10800|
# |  Daily Essentials|2024-04-09|       8000|         8000|
# | Elite Electronics|2024-04-02|      90000|        90000|
# | Elite Electronics|2024-04-03|     186000|       276000|
# | Elite Electronics|2024-04-06|     116000|       392000|
# |   Fresh Dairy Ltd|2024-04-03|       3000|         3000|
# |   Fresh Dairy Ltd|2024-04-04|       8100|        11100|
# | HomeNeeds Pvt Ltd|2024-04-04|      24500|        24500|
# | HomeNeeds Pvt Ltd|2024-04-05|      33600|        58100|
# |     Kitchen World|2024-04-05|      48000|        48000|
# |     Kitchen World|2024-04-06|      33000|        81000|
# |  National Grocers|2024-04-10|      18000|        18000|
# ...

# %%
city_revenue = final_joined_df.groupBy(
"supplier_city"
).agg(
sum("bill_amount")
.alias("total_revenue")
)

city_window = Window.orderBy(
col("total_revenue").desc()
)

city_revenue.withColumn(
"rank",
rank().over(city_window)
).show()
# Out:
# +-------------+-------------+----+
# |supplier_city|total_revenue|rank|
# +-------------+-------------+----+
# |        Delhi|       392000|   1|
# |      Kolkata|       285000|   2|
# |      Chennai|        92100|   3|
# |    Hyderabad|        63500|   4|
# |         Pune|        58100|   5|
# |    Bengaluru|        19200|   6|
# |    Ahmedabad|        18000|   7|
# |       Mumbai|        10800|   8|
# +-------------+-------------+----+

# %%
cat_revenue = final_joined_df.groupBy(
"category"
).agg(
sum("bill_amount")
.alias("total_revenue")
)

cat_window = Window.orderBy(
col("total_revenue").desc()
)

cat_revenue.withColumn(
"rank",
rank().over(cat_window)
).show()
# Out:
# +---------------+-------------+----+
# |       category|total_revenue|rank|
# +---------------+-------------+----+
# |    ELECTRONICS|       677000|   1|
# |HOME APPLIANCES|       139100|   2|
# |      GROCERIES|        73500|   3|
# |     STATIONERY|        19200|   4|
# |  PERSONAL CARE|        18800|   5|
# |          DAIRY|        11100|   6|
# +---------------+-------------+----+

# %%
pay_window = Window.partitionBy(
"payment_mode"
).orderBy(
col("bill_amount").desc()
)

final_joined_df.withColumn(
"row_num",
row_number().over(pay_window)
).filter(
col("row_num")==1
).select(
"payment_mode",
"bill_amount",
"product_name"
).show()
# Out:
# +-------------+-----------+-------------+
# | payment_mode|bill_amount| product_name|
# +-------------+-----------+-------------+
# |Bank Transfer|     186000|       Laptop|
# |         Cash|      33600|  Ceiling Fan|
# |  Credit Card|      33000|    Gas Stove|
# |   Debit Card|      24500|Mixer Grinder|
# |          UPI|     125000| Mobile Phone|
# +-------------+-----------+-------------+

# %% [markdown]
# **Part 7 — Delta Lake Core**

# %%
final_joined_df = products_df\
.join(orders_df,on="product_id")\
.join(suppliers_df,on="supplier_id")\
.join(payments_df,on="order_id")

final_joined_df.show()

# %%
new_orders_data = [
(321,114,204,"2024-04-11",3,"Delivered"),
(322,118,210,"2024-04-11",2,"Delivered")
]

new_orders_columns = [
"order_id",
"product_id",
"supplier_id",
"order_date",
"quantity",
"order_status"
]

new_orders_df = spark.createDataFrame(
new_orders_data,new_orders_columns
)

new_orders_df.write.format("delta")\
.mode("append")\
.save("retail_delta")

# %%
from delta.tables import DeltaTable

delta_table = DeltaTable.forPath(
spark,"retail_delta"
)

delta_table.update(
condition="order_id = 304",
set={"order_status":"'Delivered'"}
)

# %%
delta_table.update(
condition="payment_status = 'Pending'",
set={"payment_status":"'Paid'"}
)

# %%
delta_table.delete(
condition="order_status = 'Cancelled'"
)

# %%
clean_df = spark.read.format("delta")\
.load("retail_delta")\
.filter(
col("order_status")=="Delivered"
)

clean_df.write.format("delta")\
.mode("overwrite")\
.save("clean_orders")

# %%
spark.sql(
"DESCRIBE HISTORY delta.`retail_delta`"
).show(truncate=False)

# %%
old_df = spark.read.format("delta")\
.option("versionAsOf",0)\
.load("retail_delta")

old_df.show()

# %%
latest_df = spark.read.format("delta")\
.load("retail_delta")

old_df.subtract(latest_df).show()

# %%
spark.sql(
"VACUUM delta.`retail_delta` DRY RUN"
).show(truncate=False)

# %% [markdown]
# **Part 8 — Merge / Upsert**

# %% [markdown]
# **daily_orders_data**

# %%
daily_orders_data = [
(321,114,204,"2024-04-11",3,"Delivered"),
(322,118,210,"2024-04-11",2,"Delivered"),
(304,114,208,"2024-04-02",5,"Delivered"),
(319,112,208,"2024-04-10",2,"Delivered"),
(323,120,210,"2024-04-12",1,"Pending")
]

daily_orders_columns = [
"order_id",
"product_id",
"supplier_id",
"order_date",
"quantity",
"order_status"
]

daily_orders_df = spark.createDataFrame(
daily_orders_data,daily_orders_columns
)

# %%
orders_df.write.format("delta")\
.mode("overwrite")\
.save("orders_delta")

# %%
target_df = spark.read.format("delta")\
.load("orders_delta")

target_df.show()

# %%
daily_orders_df.createOrReplaceTempView(
"new_orders"
)

# %%
from delta.tables import DeltaTable

delta_table = DeltaTable.forPath(
spark,"orders_delta"
)

delta_table.alias("target").merge(
daily_orders_df.alias("source"),
"target.order_id = source.order_id"
).whenMatchedUpdate(set={
"product_id":"source.product_id",
"supplier_id":"source.supplier_id",
"order_date":"source.order_date",
"quantity":"source.quantity",
"order_status":"source.order_status"
}).whenNotMatchedInsert(values={
"order_id":"source.order_id",
"product_id":"source.product_id",
"supplier_id":"source.supplier_id",
"order_date":"source.order_date",
"quantity":"source.quantity",
"order_status":"source.order_status"
}).execute()

# %%
spark.read.format("delta")\
.load("orders_delta")\
.filter(col("order_id").isin(304,319))\
.show()

# %%
spark.read.format("delta")\
.load("orders_delta")\
.filter(col("order_id").isin(321,322,323))\
.show()

# %%
spark.sql(
"DESCRIBE HISTORY delta.`orders_delta`"
).show(truncate=False)

# %%
print(
"MERGE is used for incremental loads because it updates existing records and inserts new records without reloading complete data."
)

# %% [markdown]
# **Part 9 — Parquet to Delta**

# %%
products_df.write.mode("overwrite")\
.parquet("products_parquet")

# %%
parquet_df = spark.read.parquet(
"products_parquet"
)

parquet_df.show()

# %%
parquet_df.write.format("delta")\
.mode("overwrite")\
.save("products_delta")

# %%
delta_df = spark.read.format("delta")\
.load("products_delta")

delta_df.show()

# %%
print(
"Parquet supports only storage whereas Delta supports update, delete, merge, ACID and time travel."
)

# %%
from delta.tables import DeltaTable

delta_table = DeltaTable.forPath(
spark,"products_delta"
)

delta_table.update(
condition="product_id = 101",
set={"inventory_city":"'Chennai'"}
)

# %%
print(
"Delta supports updates better because it provides ACID transactions and row-level updates."
)

# %% [markdown]
# **Part 10 — DLT Assessment**

# %%
import dlt
from pyspark.sql.functions import *

# %%
import dlt
from pyspark.sql.functions import *

@dlt.table(name="bronze_orders")
def bronze_orders():

    data = [
    (301,101,201,"2024-04-01",20,"Delivered"),
    (302,102,201,"2024-04-01",35,"Delivered"),
    (303,111,204,"2024-04-02",2,"Delivered"),
    (304,114,208,"2024-04-02",5,"Pending"),
    (305,115,204,"2024-04-03",3,"Delivered"),
    (306,104,202,"2024-04-03",50,"Delivered"),
    (307,105,202,"2024-04-04",18,"Cancelled")
    ]

    columns = [
    "order_id",
    "product_id",
    "supplier_id",
    "order_date",
    "quantity",
    "order_status"
    ]

    return spark.createDataFrame(
    data,columns
    )

# %%
@dlt.table(name="silver_orders")
def silver_orders():

    return dlt.read("bronze_orders")\
    .filter(
    (col("quantity") > 0) &
    (col("order_status").isNotNull())
    ).withColumn(
    "total_revenue",
    col("quantity") * 1000
    )

# %%
@dlt.table(name="gold_city_revenue")
def gold_city_revenue():

    return dlt.read("silver_orders")\
    .groupBy("supplier_id")\
    .agg(
    sum("total_revenue")
    .alias("city_revenue")
    )

# %%
@dlt.table(name="gold_category_revenue")
def gold_category_revenue():

    return dlt.read("silver_orders")\
    .groupBy("order_status")\
    .agg(
    sum("total_revenue")
    .alias("category_revenue")
    )

# %%
print(
"Run DLT pipeline from Databricks Workflows."
)

# %%
print(
"Verify bronze, silver and gold tables in target schema."
)

# %% [markdown]
# **Part 11 — Unity Catalog and Governance**

# %%
create catalog retail_catalog;

# %%
create schema retail_catalog.retail_schema;

# %%
final_joined_df.write.format("delta")\
.mode("overwrite")\
.save("retail_uc_delta")

# %%
create table retail_catalog.retail_schema.retail_orders
using delta
location 'retail_uc_delta';

# %%
create table retail_catalog.retail_schema.city_revenue as

select supplier_city,
sum(bill_amount) as total_revenue

from retail_catalog.retail_schema.retail_orders

group by supplier_city;

# %%
print(
"Lineage can be viewed in Databricks Catalog Explorer."
)

# %%
grant select on table
retail_catalog.retail_schema.retail_orders
to `users`;

# %%
print(
"Unity Catalog provides centralized governance, access control and lineage tracking."
)
